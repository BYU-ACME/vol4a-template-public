# %% [markdown]
# # Buckingham Pi

# %%
import numpy as np
import sympy as sy

# %% [markdown]
# ## Problem 1
#
# Write an initialization method for the `BP` class that accepts a dictionary of dictionaries.
# The keys of the outer dictionary are variables, the keys of the inner dictionary are dimensions, and the values of the inner dictionary are exponents.
#
# Store the dictionary as an attribute named `variables`, a list of the variable names as an attribute named `var_names`, and a list of all the dimensions as an attribute named `dims`.

# %% [markdown]
# ## Problem 2
#
# Write a function for your class called `_construct_matrix` that generates the exponent matrix for the system as a SymPy Matrix.
# The matrix should have shape `(len(dims), len(var_names))`.
# Run this function in the initialization method and store the matrix as an attribute.

# %% [markdown]
# ## Problem 3
#
# Write a function for the class called `compute_pi_terms` that finds the powers for each variable for each nondimensional pi.
# It should return a list of dictionaries where each dictionary contains each variable and its exponent for the particular pi value.
# For example, if your variables are $x_1$, $x_2$ and $x_3$ and your pi term is $\pi_1=\frac{x_1^2}{x_2}$, then it would return `[{"x1": 2, "x2": -1, "x3": 0}]`.

# %%
class BP:
    # Problem 1
    def __init__(self, variables):

        self.variables = None
        self.var_names = None
        self.dims = None

    # Problem 2
    def _construct_matrix(self):
        
        self.dim_matrix = None
    
    # Problem 3
    def compute_pi_terms(self):
        
        pass
    
    # Problem 5
    def calculate_c(self, pi, vals):

        pass    
    
    # Problem 5
    def solve(self, c, pi, vals):
        
        pass

# %% [markdown]
# ## Problem 4
#
# Find the dimensions of the different variables in the Lotka-Volterra model and store them in a dictionary.
# Print the dictionary, then use your `compute_pi_terms` function to find the number of dimensionless constants for the system and print the result.

# %% [markdown]
# # Problem 5
#
# Add a funtion called `calculate_c` to your `BP` class that accepts a dictionary of exponents like those returned from `compute_pi_terms` and a dictionary of values for each variable.
# The values can be single numbers or numpy arrays.
# Return the value for the nondimensional quantity.
#
# Write another function called `solve` that solves for one of the variables in the system.
# It should accept a constant, a dictionary of exponents, and a dictionary of values for the variables with a value of `None` for the variable we want to solve for.
# For example, if we are solving for $x_1$, we would pass in `{"x1": None, "x2": val2, "x3": val3}`.

# %% [markdown]
# # Problem 6
#
# The file `periods.npy` contains several measurements for the period of a pendulum.
# The pendulum has a length of 1 $m$ and a mass of 5 $kg$.
# Assume that gravity has a value of 9.81 $\frac{m}{s^2}$
# First, use your `compute_pi_terms` function to find the powers of the variables needed to find the dimensionless constant.
# Then, using your `calculate_c` function and the values for the system, calculate the values for the dimensionless constant for each measurement.
# Finally, save and print the mean of the different values.

# %% [markdown]
# ## Problem 7
#
# Using your `solve` function and the constant found in the previous problem, estimate the period of a pendulum with length of 2 $m$ and a mass of 3 $kg$.

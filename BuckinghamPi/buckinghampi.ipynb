# %% [markdown]
# # Buckingham Pi

# %%
import numpy as np
import sympy as sy

# %% [markdown]
# ## Problems 1, 2, 3, & 5

# %%
class BP:
    # Problem 1
    def __init__(self, variables):

        self.variables = None
        self.var_names = None
        self.dims = None

    # Problem 2
    def _construct_matrix(self):
        
        self.dim_matrix = None
    
    # Problem 3
    def compute_pi_terms(self):        
        pass
    
    # Problem 5
    def calculate_c(self, pi, vals):
        pass    
    
    # Problem 5
    def solve(self, c, pi, vals):        
        pass

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ## Problem 6

# %% [markdown]
# ## Problem 7
